# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import keras

print('Python: {}'.format(sys.version))
print('Pandas: {}'.format(pd.__version__))
print('Numpy: {}'.format(np.__version__))
print('Sklearn: {}'.format(sklearn.__version__))
print('Matplotlib: {}'.format(matplotlib.__version__))
print('Keras: {}'.format(keras.__version__))
# Out:
# Python: 3.12.8 (tags/v3.12.8:2dc476b, Dec  3 2024, 19:30:04) [MSC v.1942 64 bit (AMD64)]
# Pandas: 2.2.3
# Numpy: 2.0.2
# Sklearn: 1.6.0
# Matplotlib: 3.10.0
# Keras: 3.7.0

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns
from tensorflow.keras import regularizers

# %% [markdown]
# <a class="anchor" id="1."></a>
# # 1.Importing the Dataset
#
# The dataset is available through the University of California, Irvine Machine learning repository. Here is the URL:
#
# http:////archive.ics.uci.edu/ml/datasets/Heart+Disease
#
# This dataset contains patient data concerning heart disease diagnosis that was collected at several locations around the world. There are 76 attributes, including age, sex, resting blood pressure, cholestoral levels, echocardiogram data, exercise habits, and many others. To data, all published studies using this data focus on a subset of 14 attributes - so we will do the same. More specifically, we will use the data collected at the Cleveland Clinic Foundation.
#
# To import the necessary data, we will use pandas' built in read_csv() function. Let's get started!

# %%
# read the csv
df= pd.read_csv('heart.csv')

# %%
# print the shape of the DataFrame, so we can see how many examples we have
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# print the last twenty or so data points
df.loc[280:]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 280    45    0   1       130   234    0        0      175      0      0.6
# 281    35    1   1       122   192    0        1      174      0      0.0
# 282    41    0   1       130   204    0        0      172      0      1.4
# 283    64    1   3       110   211    0        0      144      1      1.8
# 284    58    1   2       132   224    0        0      173      0      3.2
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 280       1   0     2       1
# 281       2   0     2       1
# 282       2   0     2       1
# 283       1   0     2       1
# 284       2   2     3       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [745 rows x 14 columns]

# %%
# drop rows with NaN values from DataFrame
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# print the shape and data type of the dataframe
print(df.shape)
print(df.dtypes)
# Out:
# (1025, 14)
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# print data characteristics, usings pandas built-in describe() function
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
# plot histograms for each variable
df.hist(figsize = (12, 12))
plt.show()

# %%
pd.crosstab(df.age,df.target).plot(kind="bar",figsize=(20,6))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,fmt='.1f')
plt.show()

# %%
age_unique=sorted(df.age.unique())
age_thalach_values=df.groupby('age')['thalach'].count().values
mean_thalach=[]
for i,age in enumerate(age_unique):
    mean_thalach.append(sum(df[df['age']==age].thalach)/age_thalach_values[i])
    
plt.figure(figsize=(10,5))
sns.pointplot(x=age_unique,y=mean_thalach,color='red',alpha=0.8)
plt.xlabel('Age',fontsize = 15,color='blue')
plt.xticks(rotation=45)
plt.ylabel('Thalach',fontsize = 15,color='blue')
plt.title('Age vs Thalach',fontsize = 15,color='blue')
plt.grid()
plt.show()

# %% [markdown]
# <a class="anchor" id="2."></a>
# # 2.Create Training and Testing Datasets
#
# Now that we have preprocessed the data appropriately, we can split it into training and testings datasets. We will use Sklearn's train_test_split() function to generate a training dataset (80 percent of the total data) and testing dataset (20 percent of the total data).

# %%
X = np.array(df.drop(['target'], axis=1))
y = np.array(df['target'])

# %%
X[0]
# Out:
# array([ 52.,   1.,   0., 125., 212.,   0.,   1., 168.,   0.,   1.,   2.,
#          2.,   3.])

# %%
mean = X.mean(axis=0)
X -= mean
std = X.std(axis=0)
X /= std

# %%
X[0]
# Out:
# array([-0.26843658,  0.66150409, -0.91575542, -0.37763552, -0.65933209,
#        -0.41887792,  0.89125488,  0.82132052, -0.71228712, -0.06088839,
#         0.99543334,  1.20922066,  1.08985168])

# %%
# create X and Y datasets for training
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, stratify=y, random_state=42, test_size = 0.2)

# %%
X_train[0]
# Out:
# array([ 0.834359  , -1.51170646, -0.91575542,  0.36487493,  0.93082177,
#         2.38733039,  0.89125488, -1.87497657, -0.71228712,  0.70540823,
#        -0.6241209 ,  2.17981673, -0.52212231])

# %% [markdown]
# <a class="anchor" id="3."></a>
# # 3.Building and Training the Neural Network
#
# Now that we have our data fully processed and split into training and testing datasets, we can begin building a neural network to solve this classification problem. Using keras, we will define a simple neural network with one hidden layer. Since this is a categorical classification problem, we will use a softmax activation function in the final layer of our network and a categorical_crossentropy loss during our training phase.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
model = Sequential([
    Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  
    Dropout(0.2),  
    Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  
    Dropout(0.2),
    Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  
    Dropout(0.2),
    Dense(4, activation='relu', kernel_regularizer=regularizers.l2(0.01)),  
    Dropout(0.2),
    Dense(1, activation='sigmoid')  
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
import matplotlib.pyplot as plt

# Train the model and store history
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1)

# Extract accuracy values
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(train_accuracy) + 1)
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.5635 - loss: 3.0097 - val_accuracy: 0.7561 - val_loss: 2.3536
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6971 - loss: 2.1895 - val_accuracy: 0.7805 - val_loss: 1.7928
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8148 - loss: 1.6765 - val_accuracy: 0.7927 - val_loss: 1.4184
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8344 - loss: 1.3280 - val_accuracy: 0.7927 - val_loss: 1.1668
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8371 - loss: 1.1013 - val_accuracy: 0.8049 - val_loss: 0.9874
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8360 - loss: 0.9526 - val_accuracy: 0.7927 - val_loss: 0.8701
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8703 - loss: 0.8117 - val_accuracy: 0.7927 - val_loss: 0.7867
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8484 - loss: 0.7569 - val_accuracy: 0.8171 - val_loss: 0.7325
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8647 - loss: 0.7031 - val_accuracy: 0.7927 - val_loss: 0.6950
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8654 - loss: 0.6638 - val_accuracy: 0.8049 - val_loss: 0.6586
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8655 - loss: 0.6210 - val_accuracy: 0.7927 - val_loss: 0.6331
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8649 - loss: 0.6182 - val_accuracy: 0.8171 - val_loss: 0.6206
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8977 - loss: 0.5767 - val_accuracy: 0.8415 - val_loss: 0.5961
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8801 - loss: 0.5735 - val_accuracy: 0.8171 - val_loss: 0.5896
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8767 - loss: 0.5603 - val_accuracy: 0.8171 - val_loss: 0.5788
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8835 - loss: 0.5378 - val_accuracy: 0.8537 - val_loss: 0.5636
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8720 - loss: 0.5379 - val_accuracy: 0.8415 - val_loss: 0.5604
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8894 - loss: 0.5297 - val_accuracy: 0.8171 - val_loss: 0.5497
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8975 - loss: 0.5378 - val_accuracy: 0.8171 - val_loss: 0.5596
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8729 - loss: 0.5290 - val_accuracy: 0.8537 - val_loss: 0.5370
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9029 - loss: 0.5287 - val_accuracy: 0.8415 - val_loss: 0.5379
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8614 - loss: 0.5240 - val_accuracy: 0.8293 - val_loss: 0.5345
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8970 - loss: 0.4884 - val_accuracy: 0.8659 - val_loss: 0.5279
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9162 - loss: 0.4873 - val_accuracy: 0.8902 - val_loss: 0.5204
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9018 - loss: 0.5061 - val_accuracy: 0.8780 - val_loss: 0.5180
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8870 - loss: 0.5032 - val_accuracy: 0.8780 - val_loss: 0.5065
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9045 - loss: 0.4952 - val_accuracy: 0.8902 - val_loss: 0.5038
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9073 - loss: 0.4966 - val_accuracy: 0.8049 - val_loss: 0.5423
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8664 - loss: 0.5029 - val_accuracy: 0.8902 - val_loss: 0.4964
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8834 - loss: 0.5053 - val_accuracy: 0.8902 - val_loss: 0.5298
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8706 - loss: 0.5086 - val_accuracy: 0.8659 - val_loss: 0.5321
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8814 - loss: 0.4926 - val_accuracy: 0.8902 - val_loss: 0.5027
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9318 - loss: 0.3892 - val_accuracy: 0.9268 - val_loss: 0.4059
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9477 - loss: 0.3652 - val_accuracy: 0.9268 - val_loss: 0.4033
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9452 - loss: 0.3760 - val_accuracy: 0.9024 - val_loss: 0.4138
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9107 - loss: 0.4271 - val_accuracy: 0.9268 - val_loss: 0.4032
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9266 - loss: 0.3874 - val_accuracy: 0.9024 - val_loss: 0.3927
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9433 - loss: 0.3802 - val_accuracy: 0.9268 - val_loss: 0.3966
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9405 - loss: 0.3723 - val_accuracy: 0.9146 - val_loss: 0.3861
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9289 - loss: 0.3815 - val_accuracy: 0.9146 - val_loss: 0.4089
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9407 - loss: 0.3748 - val_accuracy: 0.9146 - val_loss: 0.3961
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9461 - loss: 0.3663 - val_accuracy: 0.9024 - val_loss: 0.4121
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9283 - loss: 0.3874 - val_accuracy: 0.9268 - val_loss: 0.3971
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8904 - loss: 0.4426 - val_accuracy: 0.8780 - val_loss: 0.4481
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8892 - loss: 0.4369 - val_accuracy: 0.9024 - val_loss: 0.4060
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9260 - loss: 0.3973 - val_accuracy: 0.9268 - val_loss: 0.3981
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9168 - loss: 0.3997 - val_accuracy: 0.9268 - val_loss: 0.3820
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9338 - loss: 0.3726 - val_accuracy: 0.9268 - val_loss: 0.3832
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9399 - loss: 0.3672 - val_accuracy: 0.9268 - val_loss: 0.3841
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9258 - loss: 0.3919 - val_accuracy: 0.9146 - val_loss: 0.3838
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9248 - loss: 0.3865 - val_accuracy: 0.9146 - val_loss: 0.3802
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9313 - loss: 0.3705 - val_accuracy: 0.9146 - val_loss: 0.3748
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9457 - loss: 0.3676 - val_accuracy: 0.9390 - val_loss: 0.3722
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9344 - loss: 0.3747 - val_accuracy: 0.9024 - val_loss: 0.3882
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9354 - loss: 0.3700 - val_accuracy: 0.9146 - val_loss: 0.3725
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9484 - loss: 0.3556 - val_accuracy: 0.9146 - val_loss: 0.3660
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9388 - loss: 0.3657 - val_accuracy: 0.9268 - val_loss: 0.3881
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9396 - loss: 0.3733 - val_accuracy: 0.9146 - val_loss: 0.3817
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9235 - loss: 0.3770 - val_accuracy: 0.9268 - val_loss: 0.3762
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9329 - loss: 0.3733 - val_accuracy: 0.9268 - val_loss: 0.3801
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9462 - loss: 0.3528 - val_accuracy: 0.9146 - val_loss: 0.3717

# %%
# Plot accuracy values
plt.plot(epochs, train_accuracy, 'b', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy:.2f}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9518 - loss: 0.3405
# Test Accuracy: 0.96

# %%
predictions = model.predict(X_test)
predictions = (predictions > 0.5).astype(int)  # Convert probabilities to binary predictions
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %% [markdown]
# <a class="anchor" id="4."></a>
# # 4.Improving Results - A Binary Classification Problem
#
# Although we achieved promising results, we still have a fairly large error. This could be because it is very difficult to distinguish between the different severity levels of heart disease (classes 1 - 4). Let's simplify the problem by converting the data to a binary classification problem - heart disease or no heart disease.

# %% [markdown]
# <a class="anchor" id="5."></a>
# # 5.Results and Metrics
#
# The accuracy results we have been seeing are for the training data, but what about the testing dataset? If our model's cannot generalize to data that wasn't used to train them, they won't provide any utility.
#
# Let's test the performance of both our categorical model and binary model.  To do this, we will make predictions on the training dataset and calculate performance metrics using Sklearn.

# %%
cm = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("\nClassification Report:")
print(classification_report(y_test, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       100
#            1       0.97      0.95      0.96       105
#
#     accuracy                           0.96       205
#    macro avg       0.96      0.96      0.96       205
# weighted avg       0.96      0.96      0.96       205
